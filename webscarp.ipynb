# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
from datetime import date
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 3, Finished, Available, Finished)

# %%
url = 'https://yamahamusicstore.in/musical-instruments/guitars/electric-guitars/yamaha-pacifica-012-black-electric-guitar.html?gad=1&gclid=CjwKCAjwo9unBhBTEiwAipC11wTDTAqp4nUfTwsz8gBt4VLSO-HW6_dStE8HqMjgRN6hXc_mT7P2choC4kkQAvD_BwE'
headers = ({"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"})
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 4, Finished, Available, Finished)

# %%
page = requests.get(url, headers=headers)
page
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 5, Finished, Available, Finished)
# <Response [200]>

# %%
page.content

# %%
soup = BeautifulSoup(page.content, 'html.parser')
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 7, Finished, Available, Finished)

# %%
type(page.content)
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 8, Finished, Available, Finished)
# bytes

# %%
print(soup)

# %%
price = soup.find("span", class_="price").get_text()
print(price)
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 10, Finished, Available, Finished)
# ₹17,490

# %%
price_num = "".join([ele for ele in price if ele.isdigit()])
print(price_num)
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 11, Finished, Available, Finished)
# 17490

# %%
today = date.today()
print("Today's date : ", today," ",type(today))
todaytime = datetime.datetime.now()
print("Current timestamp : ", todaytime," ",type(todaytime))

# %%
from pyspark.sql import Row
df = spark.createDataFrame([
    Row(Date = today, DateTime = todaytime, Price = price_num)
])
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 13, Finished, Available, Finished)

# %%
display(df)

# %%
df.printSchema()
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 15, Finished, Available, Finished)
# root
#  |-- Date: date (nullable = true)
#  |-- DateTime: timestamp (nullable = true)
#  |-- Price: string (nullable = true)

# %%
from pyspark.sql.types import IntegerType
df2 = df.withColumn("Price",df.Price.cast(IntegerType()))
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 16, Finished, Available, Finished)

# %%
df2.printSchema()
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 17, Finished, Available, Finished)
# root
#  |-- Date: date (nullable = true)
#  |-- DateTime: timestamp (nullable = true)
#  |-- Price: integer (nullable = true)

# %%
display(df2)
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 18, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5fba4eb5-10c6-46e3-bdb8-50fafdb6459c)

# %%
delta_table_path = "Tables/Guitar0701"
df2.write.format("delta").mode("append").save(delta_table_path)
# Out:
# StatementMeta(, a039154a-4e2a-48a3-9979-df3195ece33b, 19, Finished, Available, Finished)
